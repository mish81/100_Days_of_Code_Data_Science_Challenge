# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

stocks = {'PLW': 387.00, 'CDR': 339.5, 'TEN': 349.5, '11B': 391.0}
quotations = pd.Series(data=stocks)
print(quotations)
# Out:
# PLW    387.0
# CDR    339.5
# TEN    349.5
# 11B    391.0
# dtype: float64

# %%
quotations['BBT'] = 25.5
quotations['F51'] = 19.2
print(quotations)
# Out:
# PLW    387.0
# CDR    339.5
# TEN    349.5
# 11B    391.0
# BBT     25.5
# F51     19.2
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
stocks = {
    'PLW': 387.00,
    'CDR': 339.5,
    'TEN': 349.5,
    '11B': 391.0,
    'BBT': 25.5,
    'F51': 19.2,
}
quotations = pd.Series(data=stocks)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 help(df.reset_index())
#
# NameError: name 'df' is not defined

# %%
stocks_df = pd.DataFrame(quotations).reset_index()
stocks_df.columns = ['ticker','price']
print(stocks_df)
# Out:
#   ticker  price
# 0    PLW  387.0
# 1    CDR  339.5
# 2    TEN  349.5
# 3    11B  391.0
# 4    BBT   25.5
# 5    F51   19.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
companies = pd.DataFrame({
    'company': ['Amazon','Microsoft','Facebook'],
    'price': [2375.0,178.6,179.2],
    'ticker': ['AMZN.US','MSFT.US','FB.US']
})

print(companies)
# Out:
#      company   price   ticker
# 0     Amazon  2375.0  AMZN.US
# 1  Microsoft   178.6  MSFT.US
# 2   Facebook   179.2    FB.US
